# %%
import ilang_fs as il

# %%
project_name = 'UN_GWHT'

# %%
il.setup_project(project_name, True)

# %%
data = il.raw_data_from_CSV('raw_data/ilang_UN_GWHT_data.csv', ',')

# %%
structured_data = il.structure_raw_data(data)

# %%
definition_network = il.make_rel_net(structured_data, 'Definiens', 'Definiendum')

# %%
structured_dependency_network_data = il.structure_dependency_network_data(structured_data)

# %%
# internal_dependencies = il.find_internal_dependencies(structured_dependency_network_data)

# %%
# internal_dependency_network = il.make_internal_dependency_network(internal_dependencies)

# %%
internal_term_candidates = il.internal_term_candidates(structured_dependency_network_data, conservative = True, descending = True, showcount = 20)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-1f08e4183954> in <module>()
# ----> 1 internal_term_candidates = il.internal_term_candidates(structured_dependency_network_data, conservative = True, descending = True, showcount = 20)
#
# ~/Documents/GitHub/ilang/analysis/ilang_fs.py in internal_term_candidates(structured_dependency_network_data, conservative, descending, showcount)
#     599     wordlist = list()
#     600     for i in wordcount:
# --> 601         wordlist.append((i, wordcount[i], used_in[i]['used_in_internal_terms_count']))
#     602     from operator import itemgetter
#     603     if descending == True:
#
# KeyError: 'action'

# %%
conservative = True
descending = True
showcount = 20
stopwords = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
stopterms = list()
wordcount = dict()
used_in = dict()
wordlist = list()

# %%
if conservative == True:
    for i in structured_dependency_network_data:
        stopterms.append(structured_dependency_network_data[i]['clean_definiendum'])
if conservative == False:
    for i in structured_dependency_network_data:
        for w in structured_dependency_network_data[i]['clean_definiendum'].split():
            if w not in stopwords:
                stopterms.append(w)

# %%
wordcount = dict()
for i in structured_dependency_network_data:
    for word in structured_dependency_network_data[i]['clean_definiens'].lower().split():
        if word not in stopwords:
            if word not in stopterms:
                if word not in wordcount:
                    wordcount[word] = 1
                else:
                    wordcount[word] = wordcount[word] + 1

# %%
for i in wordcount:
    w = i
    l = list()
    for j in structured_dependency_network_data:
        if w in structured_dependency_network_data[j]['clean_definiens']:
            l.append(structured_dependency_network_data[j]['definiendum'])
    used_in[w] = { 'used_in_internal_terms_count': len(l), 'used_in_internal_terms': l }

# %%
# Out:
# {'action': {'used_in_internal_terms_count': 5,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Corrective measures',
#    'Cultural landscapes',
#    'Heritage route',
#    'Integrity']},
#  'plan': {'used_in_internal_terms_count': 5,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Corrective measures',
#    'Management plan',
#    'Natural heritage',
#    'World Conservation Monitoring Centre']},
#  'future': {'used_in_internal_terms_count': 10,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Conservation',
#    'Convention concerning the protection of the world cultural and natural heritage',
#    'Identification',
#    'Integrity',
#    'Management',
#    'National protection',
#    'Presentation',
#    'Protection',
#    'Transmission']},
#  'cultural': {'used_in_internal_terms_count': 65,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Advisory bodies',
#    'Associative cultural landscape',
#    'Authenticity',
#    'Balance',
#    'Buffer zone',
#    'Canal',
#    'Clearly defined landscape',
#    'Comparative assessments',
#    'Comparative evaluations',
#    'Conservation',
#    'Convention',
#    'Convention concerning the protection of the world cultural and natural heritage',
#    'Convention for the protection of the world cultural and natural heritage',
#    'Criteria',
#    'Cultural heritage',
#    'Cultural heritage criteria',
#    'Cultural landscapes',
#    'Cultural property',
#    'Emergency assistance',
#    'Evaluation',
#    'Global Strategy',
#    'Groups of buildings',
#    'Harmonization',
#    'Heritage route',
#    'International Council of Monuments and Sites',
#    'ICOMOS evaluation',
#    'Identification',
#    'Information sources',
#    'Integrity',
#    'International assistance',
#    'International protection',
#    'Inventory of property',
#    'Justification',
#    'List of World Heritage in Danger',
#    'Management plan',
#    'Mixed property',
#    'Monuments',
#    'National protection',
#    'Natural heritage criteria',
#    'Operational Guidelines for the Implementation of the World Heritage Convention',
#    'Organically evolved landscape',
#    'Outstanding universal value',
#    'Presentation',
#    'Promotional activities',
#    'Property',
#    'Protection',
#    'Rehabilitation',
#    'Rome Centre',
#    'Series',
#    'Sites',
#    'Spirit of the Convention',
#    'State of conservation',
#    'Tentative list',
#    'Thematic studies',
#    'Training',
#    'Transmission',
#    'UNESCO',
#    'United Nations Educational, Scientific and Cultural Organization',
#    'World Heritage',
#    'World Heritage Committee',
#    'World Heritage Convention',
#    'World Heritage emblem',
#    'World Heritage List',
#    "Young People's Participation in World Heritage Preservation and Promotion"]},
#  'landscapes': {'used_in_internal_terms_count': 10,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Associative cultural landscape',
#    'Authenticity',
#    'Clearly defined landscape',
#    'Conservation',
#    'Cultural landscapes',
#    'Evaluation',
#    'Global Strategy',
#    'Organically evolved landscape',
#    'Thematic studies']},
#  'prepared': {'used_in_internal_terms_count': 4,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Data sheets',
#    'Operational Guidelines for the Implementation of the World Heritage Convention',
#    'State of conservation']},
#  'unesco': {'used_in_internal_terms_count': 91,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Advisory bodies',
#    'Associative cultural landscape',
#    'Authenticity',
#    'Authorization form',
#    'Balance',
#    'Biogeographic(al) provinces',
#    'Buffer zone',
#    'Centre',
#    'Clearly defined landscape',
#    'Comparative assessments',
#    'Comparative evaluations',
#    'Conservation',
#    'Convention concerning the protection of the world cultural and natural heritage',
#    'Corrective measures',
#    'Criteria',
#    'Cultural heritage',
#    'Cultural heritage criteria',
#    'Cultural landscapes',
#    'Deferred',
#    'Deletion',
#    'Delisting',
#    'Emergency assistance',
#    'Evaluation',
#    'Geological and physiographical formations',
#    'General Assembly of States Parties to the Convention',
#    'Global Strategy',
#    'Groups of buildings',
#    'Groups of urban buildings',
#    'Harmonization',
#    'International Centre for the Study of the Preservation and Restoration of Cultural Property (Rome Centre',
#    'International Council of Monuments and Sites',
#    'Identification',
#    'Immovable property',
#    'Inhabited historic towns',
#    'Integrity',
#    'International assistance',
#    'International protection',
#    'Inventory of property',
#    'IUCN - The World Conservation Union',
#    'Joint nomination',
#    'Justification',
#    'List of World Heritage in Danger',
#    'Management',
#    'Management plan',
#    'Mixed property',
#    'Mixed site',
#    'Monuments',
#    'Movable property',
#    'National protection',
#    'Natural area',
#    'Natural features',
#    'Natural heritage',
#    'Natural heritage criteria',
#    'Natural sites',
#    'Nomination',
#    'Nomination form',
#    'Operational Guidelines for the Implementation of the World Heritage Convention',
#    'Organically evolved landscape',
#    'Outstanding universal value',
#    'Precisely delineated [natural] areas',
#    'Preparatory assistance',
#    'Presentation',
#    'Promotional activities',
#    'Property',
#    'Protection',
#    'Reactive monitoring',
#    'Referral',
#    'Rehabilitation',
#    'Rules of Procedure',
#    'Secretariat',
#    'Series',
#    'Serial property',
#    'Sites',
#    'States Parties',
#    'Systematic monitoring and reporting',
#    'Technical co-operation',
#    'Tentative list',
#    'Thematic studies',
#    'Timetable',
#    'Training',
#    'Transmission',
#    'United Nations Educational, Scientific and Cultural Organization',
#    'World Conservation Monitoring Centre',
#    'World Heritage',
#    'World Heritage Bureau',
#    'World Heritage Committee',
#    'World Heritage emblem',
#    'World Heritage Fund',
#    'World Heritage List',
#    "Young People's Participation in World Heritage Preservation and Promotion"]},
#  'expert': {'used_in_internal_terms_count': 9,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Balance',
#    'Canal',
#    'Global Strategy',
#    'Heritage route',
#    'International Centre for the Study of the Preservation and Restoration of Cultural Property (Rome Centre',
#    'Integrity',
#    'Natural area',
#    'Outstanding universal value']},
#  'meeting': {'used_in_internal_terms_count': 15,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Balance',
#    'Canal',
#    'Cultural landscapes',
#    'Global Strategy',
#    'Heritage route',
#    'International Centre for the Study of the Preservation and Restoration of Cultural Property (Rome Centre',
#    'International Council of Monuments and Sites',
#    'Integrity',
#    'IUCN - The World Conservation Union',
#    'Natural area',
#    'Outstanding universal value',
#    'Promotional activities',
#    'Rules of Procedure',
#    'Thematic studies']},
#  'outstanding': {'used_in_internal_terms_count': 18,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Canal',
#    'Convention concerning the protection of the world cultural and natural heritage',
#    'Cultural heritage',
#    'Cultural landscapes',
#    'Global Strategy',
#    'Integrity',
#    'Mixed property',
#    'Natural heritage',
#    'Outstanding universal value',
#    'Series',
#    'Spirit of the Convention',
#    'Tentative list',
#    'Thematic studies',
#    'World Heritage',
#    'World Heritage Committee',
#    'World Heritage List',
#    'World Heritage value']},
#  'universal': {'used_in_internal_terms_count': 18,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Canal',
#    'Convention concerning the protection of the world cultural and natural heritage',
#    'Cultural heritage',
#    'Cultural landscapes',
#    'Global Strategy',
#    'Mixed property',
#    'Natural heritage',
#    'Outstanding universal value',
#    'Series',
#    'Spirit of the Convention',
#    'Tentative list',
#    'Thematic studies',
#    'United Nations Educational, Scientific and Cultural Organization',
#    'World Heritage',
#    'World Heritage Committee',
#    'World Heritage List',
#    'World Heritage value']},
#  'value': {'used_in_internal_terms_count': 21,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Canal',
#    'Convention concerning the protection of the world cultural and natural heritage',
#    'Cultural heritage',
#    'Cultural landscapes',
#    'Global Strategy',
#    'Integrity',
#    'Management',
#    'Mixed property',
#    'Natural area',
#    'Natural heritage',
#    'Outstanding universal value',
#    'Renomination',
#    'Series',
#    'Spirit of the Convention',
#    'Tentative list',
#    'Thematic studies',
#    'World Heritage',
#    'World Heritage Committee',
#    'World Heritage List',
#    'World Heritage value']},
#  'held': {'used_in_internal_terms_count': 12,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Associative cultural landscape',
#    'Authenticity',
#    'Canal',
#    'Cultural landscapes',
#    'Data sheets',
#    'Global Strategy',
#    'Heritage route',
#    'Natural area',
#    'Outstanding universal value',
#    'Thematic studies',
#    'World Heritage Youth Forum/Fora']},
#  'templin': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Action Plan for the Future']},
#  'germany': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['Action Plan for the Future', 'Training']},
#  'october': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['Action Plan for the Future', 'Global Strategy']},
#  '1993': {'used_in_internal_terms_count': 3,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Associative cultural landscape',
#    'Organization of World Heritage Cities']},
#  'see': {'used_in_internal_terms_count': 120,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Advisory bodies',
#    'Assistance',
#    'Associative cultural landscape',
#    'Authenticity',
#    'Authorization form',
#    'Bureau',
#    'Canal',
#    'Centre',
#    'CNPPA',
#    'Commission on National Parks and Protected Areas',
#    'Committee',
#    'Comparative assessments',
#    'Comparative evaluations',
#    'Conditions of authenticity',
#    'Conservation',
#    'Convention',
#    'Convention concerning the protection of the world cultural and natural heritage',
#    'Convention for the protection of the world cultural and natural heritage',
#    'Criteria',
#    'Criterion',
#    'Cultural heritage criteria',
#    'Cultural landscapes',
#    'Cultural property',
#    'Deferral',
#    'Deletion',
#    'Delisting',
#    'Designed landscape',
#    'Emblem',
#    'Emergency assistance',
#    'Evaluation',
#    'Fossil landscape',
#    'Fund',
#    'Fund for the Protection of the World Cultural and Natural Heritage',
#    'Geological and physiographical formations',
#    'Global Strategy for the Implementation of the World Heritage Convention',
#    'Global Strategy',
#    'Groups of buildings',
#    'Groups of urban buildings',
#    'Guidelines',
#    'Heritage route',
#    'Historic towns',
#    'International Centre for the Study of the Preservation and Restoration of Cultural Property (Rome Centre',
#    'International Council of Monuments and Sites',
#    'ICOMOS evaluation',
#    'ID No',
#    'Immovable property',
#    'Indicative list',
#    'Inhabited historic towns',
#    'Intergovernmental Committee for the Protection of the World Cultural and Natural Heritage',
#    'International assistance',
#    'International Centre for the Study of the Preservation and Restoration of Cultural Property',
#    'International Council of Monuments and Sites',
#    'International Union for the Conservation of Nature and Natural Resources',
#    'International protection',
#    'Inventory of property',
#    'IUCN - The World Conservation Union',
#    'IUCN evaluation',
#    'Itineraries',
#    'Joint nomination',
#    'List',
#    'List of World Heritage in Danger',
#    'Mixed site',
#    'Monuments',
#    'Movable property',
#    'Nara Conference on Authenticity in Relation to the World Heritage Convention',
#    'Nara Document on Authenticity',
#    'National protection',
#    'Natural',
#    'Natural features',
#    'Natural heritage criteria',
#    'Natural sites',
#    'Nomination',
#    'Operational Guidelines',
#    'Operational Guidelines for the Implementation of the World Heritage Convention',
#    'Organically evolved landscape',
#    'OWHC',
#    'Precisely delineated [natural] areas',
#    'Preparatory assistance',
#    'Preservation',
#    'Promotional activities',
#    'Property',
#    'Protection',
#    'Reactive monitoring',
#    'Reporting',
#    'Rome Centre',
#    'Routes',
#    'Safeguarding',
#    'Series',
#    'Serial nomination',
#    'Serial property',
#    'Serial site',
#    'Sites',
#    'Spirit of the Convention',
#    'State of conservation',
#    'Systematic monitoring and reporting',
#    'Technical evaluations',
#    'Technical co-operation',
#    'Tentative list',
#    'Test of authenticity',
#    'Thematic studies',
#    'Towns',
#    'Training',
#    'UNESCO',
#    'UNESCO World Heritage Centre',
#    'World Conservation Union',
#    'World Heritage',
#    'World Heritage Bureau',
#    'World Heritage Centre',
#    'World Heritage Convention',
#    'World Heritage Education',
#    'World Heritage Fund',
#    'World Heritage List',
#    'World Heritage logo',
#    'World Heritage value',
#    'World Heritage Youth Forum/Fora',
#    'World Heritage Youth Project',
#    "Young People's Participation in World Heritage Preservation and Promotion",
#    'Youth Forum',
#    'Youth Project']},
#  'von': {'used_in_internal_terms_count': 7,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Associative cultural landscape',
#    'Canal',
#    'Cultural landscapes',
#    'Global Strategy',
#    'Heritage route',
#    'Thematic studies']},
#  'droste': {'used_in_internal_terms_count': 7,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Associative cultural landscape',
#    'Canal',
#    'Cultural landscapes',
#    'Global Strategy',
#    'Heritage route',
#    'Thematic studies']},
#  'et': {'used_in_internal_terms_count': 63,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Associative cultural landscape',
#    'Authenticity',
#    'Authorization form',
#    'Balance',
#    'Buffer zone',
#    'Canal',
#    'Centre',
#    'Clearly defined landscape',
#    'CNPPA',
#    'Corrective measures',
#    'Cultural heritage',
#    'Cultural heritage criteria',
#    'Cultural landscapes',
#    'Cultural property',
#    'Data sheets',
#    'Deferred',
#    'Deletion',
#    'Delisting',
#    'Evaluation',
#    'General Assembly of States Parties to the Convention',
#    'Global Strategy',
#    'Groups of urban buildings',
#    'Heritage route',
#    'International Centre for the Study of the Preservation and Restoration of Cultural Property (Rome Centre',
#    'International Council of Monuments and Sites',
#    'ICOMOS evaluation',
#    'Identification number',
#    'Indicative list',
#    'Inhabited historic towns',
#    'Integrity',
#    'International assistance',
#    'IUCN - The World Conservation Union',
#    'IUCN evaluation',
#    'Joint nomination',
#    'Justification',
#    'List of World Heritage in Danger',
#    'Natural area',
#    'Natural heritage',
#    'Natural heritage criteria',
#    'Natural property',
#    'Nomination form',
#    'Operational Guidelines for the Implementation of the World Heritage Convention',
#    'Organically evolved landscape',
#    'Organization of World Heritage Cities',
#    'Outstanding universal value',
#    'Preparatory assistance',
#    'Promotional activities',
#    'Reactive monitoring',
#    'Rules of Procedure',
#    'Secretariat',
#    'Technical co-operation',
#    'Tentative list',
#    'Thematic studies',
#    'Timetable',
#    'Training',
#    'United Nations Educational, Scientific and Cultural Organization',
#    'UNESCO World Heritage Centre',
#    'World Heritage',
#    'World Heritage Bureau',
#    'World Heritage Centre',
#    'World Heritage Committee',
#    'World Heritage Youth Forum/Fora']},
#  'al': {'used_in_internal_terms_count': 118,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Advisory bodies',
#    'Assistance',
#    'Associative cultural landscape',
#    'Authenticity',
#    'Authorization form',
#    'Balance',
#    'Biogeographic(al) provinces',
#    'Buffer zone',
#    'Canal',
#    'Clearly defined landscape',
#    'CNPPA',
#    'Comparative assessments',
#    'Comparative evaluations',
#    'Conservation',
#    'Convention',
#    'Convention concerning the protection of the world cultural and natural heritage',
#    'Convention for the protection of the world cultural and natural heritage',
#    'Corrective measures',
#    'Criteria',
#    'Cultural heritage',
#    'Cultural heritage criteria',
#    'Cultural landscapes',
#    'Cultural property',
#    'Data sheets',
#    'Deferred',
#    'Deletion',
#    'Delisting',
#    'Emergency assistance',
#    'Evaluation',
#    'Geological and physiographical formations',
#    'General Assembly of States Parties to the Convention',
#    'Global Strategy for the Implementation of the World Heritage Convention',
#    'Global Strategy',
#    'Groups of buildings',
#    'Groups of urban buildings',
#    'Guidelines',
#    'Harmonization',
#    'Heritage route',
#    'International Centre for the Study of the Preservation and Restoration of Cultural Property (Rome Centre',
#    'International Council of Monuments and Sites',
#    'ICOMOS evaluation',
#    'Identification',
#    'Indicative list',
#    'Information sources',
#    'Inhabited historic towns',
#    'Integrity',
#    'International assistance',
#    'International protection',
#    'Inventory of property',
#    'IUCN - The World Conservation Union',
#    'IUCN evaluation',
#    'Joint nomination',
#    'Justification',
#    'List of World Heritage in Danger',
#    'Management',
#    'Management plan',
#    'Mixed property',
#    'Mixed site',
#    'Monuments',
#    'Movable property',
#    'National protection',
#    'Natural',
#    'Natural area',
#    'Natural features',
#    'Natural heritage',
#    'Natural heritage criteria',
#    'Natural property',
#    'Natural sites',
#    'Nomination',
#    'Nomination form',
#    'Operational Guidelines',
#    'Operational Guidelines for the Implementation of the World Heritage Convention',
#    'Organically evolved landscape',
#    'Organization of World Heritage Cities',
#    'Outstanding universal value',
#    'Precisely delineated [natural] areas',
#    'Preparatory assistance',
#    'Presentation',
#    'Preservation',
#    'Promotional activities',
#    'Property',
#    'Protection',
#    'Reactive monitoring',
#    'Rehabilitation',
#    'Renomination',
#    'Rome Centre',
#    'Safeguarding',
#    'Secretariat',
#    'Series',
#    'Serial nomination',
#    'Serial property',
#    'Serial site',
#    'Sites',
#    'Spirit of the Convention',
#    'State of conservation',
#    'Systematic monitoring and reporting',
#    'Technical evaluations',
#    'Technical co-operation',
#    'Tentative list',
#    'Thematic studies',
#    'Timetable',
#    'Training',
#    'Transmission',
#    'UNESCO',
#    'United Nations Educational, Scientific and Cultural Organization',
#    'World Conservation Monitoring Centre',
#    'World Conservation Union',
#    'World Heritage',
#    'World Heritage Bureau',
#    'World Heritage Committee',
#    'World Heritage Convention',
#    'World Heritage emblem',
#    'World Heritage Fund',
#    'World Heritage List',
#    'World Heritage value',
#    'World Heritage Youth Forum/Fora',
#    "Young People's Participation in World Heritage Preservation and Promotion"]},
#  '1995': {'used_in_internal_terms_count': 16,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Associative cultural landscape',
#    'Authenticity',
#    'Canal',
#    'Conservation',
#    'Cultural landscapes',
#    'Data sheets',
#    'Global Strategy',
#    'Heritage route',
#    'Identification',
#    'Information sources',
#    'IUCN evaluation',
#    'Nomination',
#    'Nomination form',
#    'Thematic studies',
#    'Training']},
#  'annex': {'used_in_internal_terms_count': 8,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Associative cultural landscape',
#    'Canal',
#    'Cultural landscapes',
#    'Global Strategy',
#    'Heritage route',
#    'Tentative list',
#    'Thematic studies']},
#  '1': {'used_in_internal_terms_count': 96,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Advisory bodies',
#    'Associative cultural landscape',
#    'Authenticity',
#    'Balance',
#    'Biogeographic(al) provinces',
#    'Buffer zone',
#    'Canal',
#    'Clearly defined landscape',
#    'Comparative assessments',
#    'Comparative evaluations',
#    'Conservation',
#    'Convention concerning the protection of the world cultural and natural heritage',
#    'Corrective measures',
#    'Criteria',
#    'Cultural heritage',
#    'Cultural heritage criteria',
#    'Cultural landscapes',
#    'Data sheets',
#    'Deferred',
#    'Deletion',
#    'Delisting',
#    'Emergency assistance',
#    'Evaluation',
#    'Geological and physiographical formations',
#    'Global Strategy',
#    'Groups of buildings',
#    'Groups of urban buildings',
#    'Harmonization',
#    'Heritage route',
#    'International Centre for the Study of the Preservation and Restoration of Cultural Property (Rome Centre',
#    'International Council of Monuments and Sites',
#    'ICOMOS evaluation',
#    'Identification',
#    'Immovable property',
#    'Indicative list',
#    'Information sources',
#    'Inhabited historic towns',
#    'Integrity',
#    'International assistance',
#    'International protection',
#    'Inventory of property',
#    'IUCN - The World Conservation Union',
#    'IUCN evaluation',
#    'Joint nomination',
#    'Justification',
#    'List of World Heritage in Danger',
#    'Management',
#    'Management plan',
#    'Mixed property',
#    'Mixed site',
#    'Monuments',
#    'Movable property',
#    'National protection',
#    'Natural area',
#    'Natural features',
#    'Natural heritage',
#    'Natural heritage criteria',
#    'Natural sites',
#    'Nomination',
#    'Nomination form',
#    'Operational Guidelines for the Implementation of the World Heritage Convention',
#    'Organically evolved landscape',
#    'Organization of World Heritage Cities',
#    'Outstanding universal value',
#    'Precisely delineated [natural] areas',
#    'Preparatory assistance',
#    'Presentation',
#    'Promotional activities',
#    'Property',
#    'Protection',
#    'Reactive monitoring',
#    'Referral',
#    'Rehabilitation',
#    'Rules of Procedure',
#    'Secretariat',
#    'Series',
#    'Serial property',
#    'Sites',
#    'States Parties',
#    'Systematic monitoring and reporting',
#    'Technical co-operation',
#    'Tentative list',
#    'Thematic studies',
#    'Timetable',
#    'Training',
#    'Transmission',
#    'United Nations Educational, Scientific and Cultural Organization',
#    'World Heritage',
#    'World Heritage Bureau',
#    'World Heritage Committee',
#    'World Heritage emblem',
#    'World Heritage Fund',
#    'World Heritage List',
#    'World Heritage Youth Forum/Fora',
#    "Young People's Participation in World Heritage Preservation and Promotion"]},
#  'outlines': {'used_in_internal_terms_count': 3,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Balance',
#    'World Heritage Committee']},
#  'recommendations': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['Action Plan for the Future', 'Integrity']},
#  'concerning': {'used_in_internal_terms_count': 18,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Authenticity',
#    'Convention',
#    'Convention concerning the protection of the world cultural and natural heritage',
#    'Convention for the protection of the world cultural and natural heritage',
#    'Criteria',
#    'Cultural heritage criteria',
#    'Cultural landscapes',
#    'Deletion',
#    'Groups of urban buildings',
#    'Integrity',
#    'International assistance',
#    'List of World Heritage in Danger',
#    'Management plan',
#    'Nomination',
#    'Operational Guidelines for the Implementation of the World Heritage Convention',
#    'Systematic monitoring and reporting',
#    'World Heritage Convention']},
#  'provision': {'used_in_internal_terms_count': 6,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Emergency assistance',
#    'Inhabited historic towns',
#    'International assistance',
#    'Technical co-operation',
#    'World Heritage Fund']},
#  'guidance': {'used_in_internal_terms_count': 8,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Cultural landscapes',
#    'Evaluation',
#    'Justification',
#    'Nomination',
#    'Operational Guidelines for the Implementation of the World Heritage Convention',
#    'Systematic monitoring and reporting',
#    'World Heritage emblem']},
#  'states': {'used_in_internal_terms_count': 41,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Authenticity',
#    'Authorization form',
#    'Balance',
#    'Buffer zone',
#    'Conservation',
#    'Convention concerning the protection of the world cultural and natural heritage',
#    'Deferred',
#    'Emergency assistance',
#    'Evaluation',
#    'General Assembly of States Parties to the Convention',
#    'Identification',
#    'International assistance',
#    'International protection',
#    'Inventory of property',
#    'IUCN - The World Conservation Union',
#    'Joint nomination',
#    'Justification',
#    'List of World Heritage in Danger',
#    'Management',
#    'Management plan',
#    'Mixed property',
#    'Nomination',
#    'Nomination form',
#    'Operational Guidelines for the Implementation of the World Heritage Convention',
#    'Preparatory assistance',
#    'Presentation',
#    'Protection',
#    'Reactive monitoring',
#    'Rehabilitation',
#    'Renomination',
#    'State of conservation',
#    'States Parties',
#    'Technical co-operation',
#    'Tentative list',
#    'Training',
#    'Transmission',
#    'World Heritage',
#    'World Heritage Bureau',
#    'World Heritage Committee',
#    'World Heritage Fund']},
#  'parties': {'used_in_internal_terms_count': 31,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Conservation',
#    'Convention concerning the protection of the world cultural and natural heritage',
#    'Deferred',
#    'Emergency assistance',
#    'Evaluation',
#    'General Assembly of States Parties to the Convention',
#    'Identification',
#    'International assistance',
#    'International protection',
#    'Inventory of property',
#    'Justification',
#    'Management plan',
#    'Mixed property',
#    'Nomination',
#    'Nomination form',
#    'Operational Guidelines for the Implementation of the World Heritage Convention',
#    'Preparatory assistance',
#    'Presentation',
#    'Protection',
#    'Reactive monitoring',
#    'Rehabilitation',
#    'State of conservation',
#    'States Parties',
#    'Technical co-operation',
#    'Tentative list',
#    'Training',
#    'Transmission',
#    'World Heritage Bureau',
#    'World Heritage Committee',
#    'World Heritage Fund']},
#  'identification': {'used_in_internal_terms_count': 12,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Conservation',
#    'Convention concerning the protection of the world cultural and natural heritage',
#    'Identification',
#    'Identification number',
#    'ID No',
#    'Integrity',
#    'National protection',
#    'Presentation',
#    'Protection',
#    'Rehabilitation',
#    'Transmission']},
#  'assessment': {'used_in_internal_terms_count': 4,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Comparative assessments',
#    'Comparative evaluations',
#    'Deferred']},
#  'nomination': {'used_in_internal_terms_count': 32,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Authenticity',
#    'Authorization form',
#    'Balance',
#    'Biogeographic(al) provinces',
#    'Buffer zone',
#    'Comparative assessments',
#    'Comparative evaluations',
#    'Conservation',
#    'Data sheets',
#    'Deferred',
#    'Evaluation',
#    'ICOMOS evaluation',
#    'Identification',
#    'Identification number',
#    'Immovable property',
#    'Integrity',
#    'IUCN evaluation',
#    'Joint nomination',
#    'Justification',
#    'Movable property',
#    'Natural area',
#    'Nomination',
#    'Nomination form',
#    'Operational Guidelines for the Implementation of the World Heritage Convention',
#    'Outstanding universal value',
#    'Referral',
#    'Renomination',
#    'Series',
#    'Tentative list',
#    'Timetable',
#    'World Heritage Committee']},
#  'management': {'used_in_internal_terms_count': 12,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Authenticity',
#    'CNPPA',
#    'Conservation',
#    'Criteria',
#    'Cultural heritage criteria',
#    'Integrity',
#    'Management',
#    'Management plan',
#    'Natural area',
#    'Organization of World Heritage Cities',
#    'Secretariat']},
#  'inclusion': {'used_in_internal_terms_count': 28,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Associative cultural landscape',
#    'Authenticity',
#    'Corrective measures',
#    'Criteria',
#    'Cultural landscapes',
#    'Deferred',
#    'Deletion',
#    'Delisting',
#    'Emergency assistance',
#    'Groups of urban buildings',
#    'Harmonization',
#    'Identification',
#    'Integrity',
#    'Inventory of property',
#    'IUCN - The World Conservation Union',
#    'IUCN evaluation',
#    'Justification',
#    'List of World Heritage in Danger',
#    'Management',
#    'Management plan',
#    'Movable property',
#    'Nomination',
#    'Nomination form',
#    'Operational Guidelines for the Implementation of the World Heritage Convention',
#    'Series',
#    'Tentative list',
#    'Thematic studies']},
#  'world': {'used_in_internal_terms_count': 107,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Advisory bodies',
#    'Associative cultural landscape',
#    'Authenticity',
#    'Balance',
#    'Biogeographic(al) provinces',
#    'Bureau',
#    'Centre',
#    'Clearly defined landscape',
#    'CNPPA',
#    'Committee',
#    'Comparative assessments',
#    'Conservation',
#    'Convention',
#    'Convention concerning the protection of the world cultural and natural heritage',
#    'Convention for the protection of the world cultural and natural heritage',
#    'Corrective measures',
#    'Criteria',
#    'Cultural heritage criteria',
#    'Cultural landscapes',
#    'Cultural property',
#    'Data sheets',
#    'Deferred',
#    'Deletion',
#    'Delisting',
#    'Emblem',
#    'Emergency assistance',
#    'Evaluation',
#    'Fund',
#    'Fund for the Protection of the World Cultural and Natural Heritage',
#    'Global Strategy',
#    'Groups of urban buildings',
#    'Guidelines',
#    'Harmonization',
#    'International Centre for the Study of the Preservation and Restoration of Cultural Property (Rome Centre',
#    'International Council of Monuments and Sites',
#    'ICOMOS evaluation',
#    'Identification',
#    'Identification number',
#    'Inscription',
#    'Integrity',
#    'Intergovernmental Committee for the Protection of the World Cultural and Natural Heritage',
#    'International assistance',
#    'International Union for the Conservation of Nature and Natural Resources',
#    'International protection',
#    'Inventory of property',
#    'IUCN - The World Conservation Union',
#    'IUCN evaluation',
#    'Joint nomination',
#    'Justification',
#    'List',
#    'List of World Heritage in Danger',
#    'Management',
#    'Management plan',
#    'Mixed property',
#    'Mixed site',
#    'Movable property',
#    'National protection',
#    'Natural area',
#    'Natural heritage criteria',
#    'Natural property',
#    'Nomination',
#    'Nomination form',
#    'Operational Guidelines',
#    'Operational Guidelines for the Implementation of the World Heritage Convention',
#    'Organically evolved landscape',
#    'Organization of World Heritage Cities',
#    'Outstanding universal value',
#    'OWHC',
#    'Preparatory assistance',
#    'Presentation',
#    'Preservation',
#    'Promotional activities',
#    'Property',
#    'Protection',
#    'Reactive monitoring',
#    'Rehabilitation',
#    'Renomination',
#    'Rules of Procedure',
#    'Secretariat',
#    'Series',
#    'Serial property',
#    'State of conservation',
#    'States Parties',
#    'Systematic monitoring and reporting',
#    'Technical co-operation',
#    'Tentative list',
#    'Thematic studies',
#    'Training',
#    'Transmission',
#    'United Nations Educational, Scientific and Cultural Organization',
#    'World Conservation Monitoring Centre',
#    'World Conservation Union',
#    'World Heritage',
#    'World Heritage Bureau',
#    'World Heritage Committee',
#    'World Heritage Convention',
#    'World Heritage Education',
#    'World Heritage emblem',
#    'World Heritage Fund',
#    'World Heritage List',
#    'World Heritage logo',
#    'World Heritage Youth Forum/Fora',
#    'World Heritage Youth Project',
#    "Young People's Participation in World Heritage Preservation and Promotion",
#    'Youth Forum',
#    'Youth Project']},
#  'heritage': {'used_in_internal_terms_count': 118,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Advisory bodies',
#    'Associative cultural landscape',
#    'Authenticity',
#    'Balance',
#    'Biogeographic(al) provinces',
#    'Bureau',
#    'Canal',
#    'Centre',
#    'Clearly defined landscape',
#    'Committee',
#    'Comparative assessments',
#    'Conservation',
#    'Convention',
#    'Convention concerning the protection of the world cultural and natural heritage',
#    'Convention for the protection of the world cultural and natural heritage',
#    'Corrective measures',
#    'Criteria',
#    'Cultural heritage',
#    'Cultural heritage criteria',
#    'Cultural landscapes',
#    'Cultural property',
#    'Deferred',
#    'Deletion',
#    'Delisting',
#    'Emblem',
#    'Emergency assistance',
#    'Evaluation',
#    'Fund',
#    'Fund for the Protection of the World Cultural and Natural Heritage',
#    'Geological and physiographical formations',
#    'Global Strategy',
#    'Groups of buildings',
#    'Groups of urban buildings',
#    'Guidelines',
#    'Harmonization',
#    'Heritage route',
#    'International Centre for the Study of the Preservation and Restoration of Cultural Property (Rome Centre',
#    'International Council of Monuments and Sites',
#    'ICOMOS evaluation',
#    'Identification',
#    'Identification number',
#    'Information sources',
#    'Inscription',
#    'Integrity',
#    'Intergovernmental Committee for the Protection of the World Cultural and Natural Heritage',
#    'International assistance',
#    'International protection',
#    'Inventory of property',
#    'IUCN - The World Conservation Union',
#    'IUCN evaluation',
#    'Itineraries',
#    'Joint nomination',
#    'Justification',
#    'List',
#    'List of World Heritage in Danger',
#    'Management',
#    'Management plan',
#    'Mixed property',
#    'Mixed site',
#    'Monuments',
#    'Movable property',
#    'National protection',
#    'Natural area',
#    'Natural features',
#    'Natural heritage',
#    'Natural heritage criteria',
#    'Natural property',
#    'Natural sites',
#    'Nomination',
#    'Nomination form',
#    'Operational Guidelines',
#    'Operational Guidelines for the Implementation of the World Heritage Convention',
#    'Organically evolved landscape',
#    'Organization of World Heritage Cities',
#    'Outstanding universal value',
#    'OWHC',
#    'Precisely delineated [natural] areas',
#    'Preparatory assistance',
#    'Presentation',
#    'Preservation',
#    'Promotional activities',
#    'Property',
#    'Protection',
#    'Reactive monitoring',
#    'Rehabilitation',
#    'Renomination',
#    'Routes',
#    'Rules of Procedure',
#    'Secretariat',
#    'Series',
#    'Serial property',
#    'Sites',
#    'Spirit of the Convention',
#    'State of conservation',
#    'States Parties',
#    'Systematic monitoring and reporting',
#    'Technical co-operation',
#    'Tentative list',
#    'Thematic studies',
#    'Training',
#    'Transmission',
#    'United Nations Educational, Scientific and Cultural Organization',
#    'World Conservation Monitoring Centre',
#    'World Heritage',
#    'World Heritage Bureau',
#    'World Heritage Committee',
#    'World Heritage Convention',
#    'World Heritage Education',
#    'World Heritage emblem',
#    'World Heritage Fund',
#    'World Heritage List',
#    'World Heritage logo',
#    'World Heritage Youth Forum/Fora',
#    'World Heritage Youth Project',
#    "Young People's Participation in World Heritage Preservation and Promotion",
#    'Youth Forum',
#    'Youth Project']},
#  'list': {'used_in_internal_terms_count': 60,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Associative cultural landscape',
#    'Authenticity',
#    'Balance',
#    'Biogeographic(al) provinces',
#    'CNPPA',
#    'Comparative assessments',
#    'Comparative evaluations',
#    'Conservation',
#    'Convention concerning the protection of the world cultural and natural heritage',
#    'Corrective measures',
#    'Criteria',
#    'Cultural heritage criteria',
#    'Cultural landscapes',
#    'Cultural property',
#    'Deferred',
#    'Deletion',
#    'Delisting',
#    'Emergency assistance',
#    'Global Strategy',
#    'Groups of urban buildings',
#    'Harmonization',
#    'International Centre for the Study of the Preservation and Restoration of Cultural Property (Rome Centre',
#    'International Council of Monuments and Sites',
#    'Identification',
#    'Indicative list',
#    'Inhabited historic towns',
#    'Inscription',
#    'Integrity',
#    'Inventory of property',
#    'IUCN - The World Conservation Union',
#    'IUCN evaluation',
#    'Joint nomination',
#    'Justification',
#    'List',
#    'List of World Heritage in Danger',
#    'Management',
#    'Management plan',
#    'Mixed property',
#    'Mixed site',
#    'Movable property',
#    'Natural heritage criteria',
#    'Natural property',
#    'Nomination',
#    'Nomination form',
#    'Operational Guidelines for the Implementation of the World Heritage Convention',
#    'Outstanding universal value',
#    'Reactive monitoring',
#    'Renomination',
#    'Series',
#    'Serial property',
#    'State of conservation',
#    'Systematic monitoring and reporting',
#    'Technical co-operation',
#    'Tentative list',
#    'Thematic studies',
#    'Training',
#    'World Heritage',
#    'World Heritage Committee',
#    'World Heritage List']},
#  'preparation': {'used_in_internal_terms_count': 4,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Evaluation',
#    'Nomination',
#    'Promotional activities']},
#  'thematic': {'used_in_internal_terms_count': 4,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Cultural landscapes',
#    'Global Strategy',
#    'Thematic studies']},
#  'study': {'used_in_internal_terms_count': 4,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Advisory bodies',
#    'Deferred',
#    'Rome Centre']},
#  'adopted': {'used_in_internal_terms_count': 11,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Associative cultural landscape',
#    'Clearly defined landscape',
#    'Convention concerning the protection of the world cultural and natural heritage',
#    'Cultural landscapes',
#    'Global Strategy',
#    'Groups of urban buildings',
#    'Operational Guidelines for the Implementation of the World Heritage Convention',
#    'Organically evolved landscape',
#    'Rules of Procedure',
#    'World Heritage emblem']},
#  'committee': {'used_in_internal_terms_count': 45,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Advisory bodies',
#    'Associative cultural landscape',
#    'Authenticity',
#    'Balance',
#    'Clearly defined landscape',
#    'Committee',
#    'Conservation',
#    'Convention concerning the protection of the world cultural and natural heritage',
#    'Criteria',
#    'Cultural landscapes',
#    'Deferred',
#    'Delisting',
#    'Evaluation',
#    'Global Strategy',
#    'Groups of urban buildings',
#    'Harmonization',
#    'International Centre for the Study of the Preservation and Restoration of Cultural Property (Rome Centre',
#    'International Council of Monuments and Sites',
#    'ICOMOS evaluation',
#    'Integrity',
#    'Intergovernmental Committee for the Protection of the World Cultural and Natural Heritage',
#    'International assistance',
#    'Inventory of property',
#    'IUCN - The World Conservation Union',
#    'IUCN evaluation',
#    'List of World Heritage in Danger',
#    'Mixed site',
#    'Movable property',
#    'Natural area',
#    'Operational Guidelines for the Implementation of the World Heritage Convention',
#    'Organically evolved landscape',
#    'Outstanding universal value',
#    'Reactive monitoring',
#    'Referral',
#    'Rules of Procedure',
#    'Secretariat',
#    'State of conservation',
#    'Systematic monitoring and reporting',
#    'Tentative list',
#    'Training',
#    'United Nations Educational, Scientific and Cultural Organization',
#    'World Heritage Bureau',
#    'World Heritage Committee',
#    'World Heritage emblem']},
#  'seventeenth': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Convention concerning the protection of the world cultural and natural heritage']},
#  'session': {'used_in_internal_terms_count': 16,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Associative cultural landscape',
#    'Balance',
#    'Clearly defined landscape',
#    'Convention concerning the protection of the world cultural and natural heritage',
#    'Cultural landscapes',
#    'Global Strategy',
#    'Integrity',
#    'Natural area',
#    'Organically evolved landscape',
#    'Outstanding universal value',
#    'Rules of Procedure',
#    'Training',
#    'World Heritage',
#    'World Heritage Bureau',
#    'World Heritage emblem']},
#  '4': {'used_in_internal_terms_count': 45,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Advisory bodies',
#    'Associative cultural landscape',
#    'Authenticity',
#    'Balance',
#    'Canal',
#    'Clearly defined landscape',
#    'Comparative assessments',
#    'Conservation',
#    'Convention concerning the protection of the world cultural and natural heritage',
#    'Corrective measures',
#    'Criteria',
#    'Cultural heritage criteria',
#    'Cultural landscapes',
#    'Deferred',
#    'Deletion',
#    'Global Strategy',
#    'Groups of urban buildings',
#    'Harmonization',
#    'Heritage route',
#    'Identification',
#    'Integrity',
#    'IUCN - The World Conservation Union',
#    'Justification',
#    'List of World Heritage in Danger',
#    'Management plan',
#    'Mixed site',
#    'National protection',
#    'Natural area',
#    'Natural heritage criteria',
#    'Operational Guidelines for the Implementation of the World Heritage Convention',
#    'Organically evolved landscape',
#    'Outstanding universal value',
#    'Reactive monitoring',
#    'Referral',
#    'Secretariat',
#    'States Parties',
#    'Systematic monitoring and reporting',
#    'Technical co-operation',
#    'Tentative list',
#    'Training',
#    'United Nations Educational, Scientific and Cultural Organization',
#    'World Heritage Bureau',
#    'World Heritage emblem',
#    "Young People's Participation in World Heritage Preservation and Promotion"]},
#  'february': {'used_in_internal_terms_count': 59,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Advisory bodies',
#    'Associative cultural landscape',
#    'Authenticity',
#    'Balance',
#    'Biogeographic(al) provinces',
#    'Buffer zone',
#    'Clearly defined landscape',
#    'Comparative assessments',
#    'Comparative evaluations',
#    'Conservation',
#    'Corrective measures',
#    'Criteria',
#    'Cultural heritage criteria',
#    'Cultural landscapes',
#    'Deferred',
#    'Deletion',
#    'Delisting',
#    'Emergency assistance',
#    'Evaluation',
#    'Groups of urban buildings',
#    'Harmonization',
#    'Identification',
#    'Immovable property',
#    'Inhabited historic towns',
#    'Integrity',
#    'International assistance',
#    'Joint nomination',
#    'Justification',
#    'List of World Heritage in Danger',
#    'Management',
#    'Management plan',
#    'Mixed property',
#    'Mixed site',
#    'Movable property',
#    'Natural heritage criteria',
#    'Nomination',
#    'Operational Guidelines for the Implementation of the World Heritage Convention',
#    'Organically evolved landscape',
#    'Outstanding universal value',
#    'Preparatory assistance',
#    'Promotional activities',
#    'Property',
#    'Protection',
#    'Reactive monitoring',
#    'Referral',
#    'Series',
#    'Serial property',
#    'Sites',
#    'Systematic monitoring and reporting',
#    'Technical co-operation',
#    'Tentative list',
#    'Timetable',
#    'Training',
#    'World Heritage',
#    'World Heritage Bureau',
#    'World Heritage Committee',
#    'World Heritage emblem',
#    'World Heritage List']},
#  '1994': {'used_in_internal_terms_count': 8,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Associative cultural landscape',
#    'Authenticity',
#    'Canal',
#    'Global Strategy',
#    'Heritage route',
#    'World Heritage emblem',
#    "Young People's Participation in World Heritage Preservation and Promotion"]},
#  '55-56': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['Action Plan for the Future', 'Training']},
#  'vii': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Action Plan for the Future']},
#  'article': {'used_in_internal_terms_count': 37,
#   'used_in_internal_terms': ['Advisory bodies',
#    'Conservation',
#    'Criteria',
#    'Cultural heritage',
#    'Cultural landscapes',
#    'Geological and physiographical formations',
#    'Groups of buildings',
#    'International Centre for the Study of the Preservation and Restoration of Cultural Property (Rome Centre',
#    'International Council of Monuments and Sites',
#    'Identification',
#    'Indicative list',
#    'International assistance',
#    'International protection',
#    'Inventory of property',
#    'IUCN - The World Conservation Union',
#    'List of World Heritage in Danger',
#    'Monuments',
#    'National protection',
#    'Natural features',
#    'Natural heritage',
#    'Natural sites',
#    'Precisely delineated [natural] areas',
#    'Presentation',
#    'Promotional activities',
#    'Protection',
#    'Rehabilitation',
#    'Rules of Procedure',
#    'Secretariat',
#    'Sites',
#    'Technical co-operation',
#    'Tentative list',
#    'Training',
#    'Transmission',
#    'United Nations Educational, Scientific and Cultural Organization',
#    'World Heritage Committee',
#    'World Heritage Fund',
#    'World Heritage List']},
#  '83': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['Advisory bodies', 'Corrective measures']},
#  'convention': {'used_in_internal_terms_count': 64,
#   'used_in_internal_terms': ['Advisory bodies',
#    'Authenticity',
#    'Balance',
#    'Conservation',
#    'Convention',
#    'Convention concerning the protection of the world cultural and natural heritage',
#    'Convention for the protection of the world cultural and natural heritage',
#    'Criteria',
#    'Cultural heritage',
#    'Cultural landscapes',
#    'Geological and physiographical formations',
#    'General Assembly of States Parties to the Convention',
#    'Groups of buildings',
#    'Groups of urban buildings',
#    'Guidelines',
#    'Harmonization',
#    'International Centre for the Study of the Preservation and Restoration of Cultural Property (Rome Centre',
#    'International Council of Monuments and Sites',
#    'Identification',
#    'Implementation',
#    'Immovable property',
#    'Indicative list',
#    'Integrity',
#    'International assistance',
#    'International protection',
#    'Inventory of property',
#    'IUCN - The World Conservation Union',
#    'List of World Heritage in Danger',
#    'Management plan',
#    'Monuments',
#    'National protection',
#    'Natural features',
#    'Natural heritage',
#    'Natural sites',
#    'Nomination',
#    'Operational Guidelines',
#    'Operational Guidelines for the Implementation of the World Heritage Convention',
#    'Organization of World Heritage Cities',
#    'Outstanding universal value',
#    'Precisely delineated [natural] areas',
#    'Presentation',
#    'Preservation',
#    'Promotional activities',
#    'Property',
#    'Protection',
#    'Rehabilitation',
#    'Renomination',
#    'Rules of Procedure',
#    'Safeguarding',
#    'Secretariat',
#    'Sites',
#    'Spirit of the Convention',
#    'States Parties',
#    'Technical co-operation',
#    'Tentative list',
#    'Training',
#    'Transmission',
#    'United Nations Educational, Scientific and Cultural Organization',
#    'World Conservation Monitoring Centre',
#    'World Heritage',
#    'World Heritage Committee',
#    'World Heritage Convention',
#    'World Heritage Fund',
#    'World Heritage List']},
#  'establishes': {'used_in_internal_terms_count': 7,
#   'used_in_internal_terms': ['Advisory bodies',
#    'Convention concerning the protection of the world cultural and natural heritage',
#    'Evaluation',
#    'International assistance',
#    'Inventory of property',
#    'Technical co-operation',
#    'Tentative list']},
#  'international': {'used_in_internal_terms_count': 24,
#   'used_in_internal_terms': ['Advisory bodies',
#    'Assistance',
#    'Balance',
#    'Convention concerning the protection of the world cultural and natural heritage',
#    'Emergency assistance',
#    'Evaluation',
# ...
#  'centres': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Inhabited historic towns']},
#  'cover': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['Inhabited historic towns',
#    'World Heritage emblem']},
#  'exactly': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Inhabited historic towns']},
#  'ancient': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Inhabited historic towns']},
#  'enclosed': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Inhabited historic towns']},
#  'cities': {'used_in_internal_terms_count': 3,
#   'used_in_internal_terms': ['Inhabited historic towns',
#    'Organization of World Heritage Cities',
#    'OWHC']},
#  'determine': {'used_in_internal_terms_count': 5,
#   'used_in_internal_terms': ['Buffer zone',
#    'Deletion',
#    'Inhabited historic towns',
#    'List of World Heritage in Danger',
#    'World Heritage Committee']},
#  'widest': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['Inhabited historic towns', 'Tentative list']},
#  'dimensions': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Inhabited historic towns']},
#  'immediate': {'used_in_internal_terms_count': 3,
#   'used_in_internal_terms': ['Inhabited historic towns',
#    'List of World Heritage in Danger',
#    'World Heritage Bureau']},
#  'surroundings;': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Inhabited historic towns']},
#  'sectors': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['Inhabited historic towns',
#    'Reactive monitoring']},
#  'isolated': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Inhabited historic towns']},
#  'units': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Inhabited historic towns']},
#  'residual': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Inhabited historic towns']},
#  'survived': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Inhabited historic towns']},
#  'coherent': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Inhabited historic towns']},
#  'disappeared': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Inhabited historic towns']},
#  'cases': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['Inhabited historic towns',
#    'Outstanding universal value']},
#  'surviving': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Inhabited historic towns']},
#  'bear': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Inhabited historic towns']},
#  'sufficient': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['Inhabited historic towns', 'Integrity']},
#  'testimony': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Inhabited historic towns']},
#  'former': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['International Centre for the Study of the Preservation and Restoration of Cultural Property (Rome Centre',
#    'Inhabited historic towns']},
#  'whole': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['Inhabited historic towns', 'World Heritage']},
#  'inscribing': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Inscription']},
#  'directly': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  '44': {'used_in_internal_terms_count': 5,
#   'used_in_internal_terms': ['Integrity',
#    'Justification',
#    'Management plan',
#    'Natural heritage criteria',
#    'Tentative list']},
#  'fulfils': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  '45': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['Integrity',
#    'United Nations Educational, Scientific and Cultural Organization']},
#  'summarised': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  'follows': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['Integrity', 'Justification']},
#  'described': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['Integrity', 'Mixed site']},
#  '44ai': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  'key': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['Integrity', 'Outstanding universal value']},
#  'interrelated': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  'interdependent': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  'relationships': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  '44aii': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  'demonstrate': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  'aspects': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  'processes': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['Integrity', 'Natural area']},
#  'long-term': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  'ecosystems': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['Integrity',
#    'World Conservation Monitoring Centre']},
#  '44aiii': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  'beauty': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['Integrity', 'Natural heritage']},
#  'site': {'used_in_internal_terms_count': 15,
#   'used_in_internal_terms': ['Advisory bodies',
#    'Balance',
#    'Cultural heritage',
#    'Evaluation',
#    'Immovable property',
#    'Integrity',
#    'Natural area',
#    'Natural heritage',
#    'Natural sites',
#    'Organization of World Heritage Cities',
#    'Outstanding universal value',
#    'Property',
#    'Reactive monitoring',
#    'Sites',
#    'Systematic monitoring and reporting']},
#  '44aiv': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  'habitats': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  'diverse': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['Integrity',
#    'IUCN - The World Conservation Union']},
#  'fauna': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  'flora': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  'biogeographic': {'used_in_internal_terms_count': 5,
#   'used_in_internal_terms': ['Balance',
#    'Biogeographic(al) provinces',
#    'Integrity',
#    'Series',
#    'Tentative list']},
#  'province': {'used_in_internal_terms_count': 4,
#   'used_in_internal_terms': ['Biogeographic(al) provinces',
#    'Integrity',
#    'Series',
#    'Tentative list']},
#  '13-14': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  'furthermore': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  'examining': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['Integrity', 'Referral']},
#  '19': {'used_in_internal_terms_count': 94,
#   'used_in_internal_terms': ['Action Plan for the Future',
#    'Advisory bodies',
#    'Associative cultural landscape',
#    'Authenticity',
#    'Balance',
#    'Biogeographic(al) provinces',
#    'Buffer zone',
#    'Canal',
#    'Clearly defined landscape',
#    'Comparative assessments',
#    'Comparative evaluations',
#    'Conservation',
#    'Convention concerning the protection of the world cultural and natural heritage',
#    'Corrective measures',
#    'Criteria',
#    'Cultural heritage',
#    'Cultural heritage criteria',
#    'Cultural landscapes',
#    'Data sheets',
#    'Deferred',
#    'Deletion',
#    'Delisting',
#    'Emergency assistance',
#    'Evaluation',
#    'Geological and physiographical formations',
#    'Global Strategy',
#    'Groups of buildings',
#    'Groups of urban buildings',
#    'Harmonization',
#    'Heritage route',
#    'International Centre for the Study of the Preservation and Restoration of Cultural Property (Rome Centre',
#    'International Council of Monuments and Sites',
#    'ICOMOS evaluation',
#    'Identification',
#    'Immovable property',
#    'Information sources',
#    'Inhabited historic towns',
#    'Integrity',
#    'International assistance',
#    'International protection',
#    'Inventory of property',
#    'IUCN - The World Conservation Union',
#    'IUCN evaluation',
#    'Joint nomination',
#    'Justification',
#    'List of World Heritage in Danger',
#    'Management',
#    'Management plan',
#    'Mixed property',
#    'Mixed site',
#    'Monuments',
#    'Movable property',
#    'National protection',
#    'Natural area',
#    'Natural features',
#    'Natural heritage',
#    'Natural heritage criteria',
#    'Natural sites',
#    'Nomination',
#    'Nomination form',
#    'Operational Guidelines for the Implementation of the World Heritage Convention',
#    'Organically evolved landscape',
#    'Organization of World Heritage Cities',
#    'Outstanding universal value',
#    'Precisely delineated [natural] areas',
#    'Preparatory assistance',
#    'Presentation',
#    'Promotional activities',
#    'Property',
#    'Protection',
#    'Reactive monitoring',
#    'Referral',
#    'Rehabilitation',
#    'Secretariat',
#    'Series',
#    'Serial property',
#    'Sites',
#    'States Parties',
#    'Systematic monitoring and reporting',
#    'Technical co-operation',
#    'Tentative list',
#    'Thematic studies',
#    'Timetable',
#    'Training',
#    'Transmission',
#    'United Nations Educational, Scientific and Cultural Organization',
#    'World Heritage',
#    'World Heritage Bureau',
#    'World Heritage Committee',
#    'World Heritage emblem',
#    'World Heritage Fund',
#    'World Heritage List',
#    'World Heritage Youth Forum/Fora',
#    "Young People's Participation in World Heritage Preservation and Promotion"]},
#  'criterion': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  '80': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['Integrity',
#    'IUCN - The World Conservation Union']},
#  'amenable': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  'correction': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  'administrative': {'used_in_internal_terms_count': 3,
#   'used_in_internal_terms': ['Integrity',
#    'Organically evolved landscape',
#    'Secretariat']},
#  'legislative': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  'cancelling': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  'major': {'used_in_internal_terms_count': 4,
#   'used_in_internal_terms': ['Integrity',
#    'List of World Heritage in Danger',
#    'Operational Guidelines for the Implementation of the World Heritage Convention',
#    'World Heritage Committee']},
#  'public': {'used_in_internal_terms_count': 3,
#   'used_in_internal_terms': ['Integrity',
#    'Joint nomination',
#    'List of World Heritage in Danger']},
#  'project': {'used_in_internal_terms_count': 6,
#   'used_in_internal_terms': ['Balance',
#    'Integrity',
#    'International assistance',
#    'List of World Heritage in Danger',
#    'World Heritage Youth Forum/Fora',
#    "Young People's Participation in World Heritage Preservation and Promotion"]},
#  'improvement': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  'status': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  'occasion': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  'bii': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['Integrity', 'Management plan']},
#  'possibility': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  'applying': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  'thus': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['Integrity',
#    'Organization of World Heritage Cities']},
#  'common': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  'approach': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['Integrity']},
#  'collective': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['International assistance',
#    'Spirit of the Convention']},
#  'participation': {'used_in_internal_terms_count': 8,
#   'used_in_internal_terms': ['International assistance',
#    'Promotional activities',
#    'World Heritage Education',
#    'World Heritage Youth Forum/Fora',
#    'World Heritage Youth Project',
#    "Young People's Participation in World Heritage Preservation and Promotion",
#    'Youth Forum',
#    'Youth Project']},
#  'community': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['International assistance']},
#  'fundamental': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['International assistance',
#    'United Nations Educational, Scientific and Cultural Organization']},
#  'tools': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['International assistance']},
#  'preamble': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['International assistance', 'World Heritage']},
#  'includes': {'used_in_internal_terms_count': 4,
#   'used_in_internal_terms': ['International assistance',
#    'Justification',
#    'Natural area',
#    'Training']},
#  'significant': {'used_in_internal_terms_count': 4,
#   'used_in_internal_terms': ['Associative cultural landscape',
#    'International assistance',
#    'Mixed property',
#    'Organically evolved landscape']},
#  'detail': {'used_in_internal_terms_count': 4,
#   'used_in_internal_terms': ['Authenticity',
#    'Buffer zone',
#    'International assistance',
#    'Operational Guidelines for the Implementation of the World Heritage Convention']},
#  'articles': {'used_in_internal_terms_count': 4,
#   'used_in_internal_terms': ['International assistance',
#    'National protection',
#    'Training',
#    'World Heritage List']},
#  '19-26': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['International assistance']},
#  'secure': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['International assistance']},
#  'rehabilitation': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['International assistance', 'Rehabilitation']},
#  'describes': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['International assistance', 'Mixed site']},
#  'co-operation': {'used_in_internal_terms_count': 4,
#   'used_in_internal_terms': ['International assistance',
#    'International protection',
#    'Technical co-operation',
#    'World Heritage Fund']},
#  'deadlines': {'used_in_internal_terms_count': 2,
#   'used_in_internal_terms': ['International assistance', 'Timetable']},
#  'order': {'used_in_internal_terms_count': 5,
#   'used_in_internal_terms': ['International assistance',
#    'Joint nomination',
#    'Tentative list',
#    'United Nations Educational, Scientific and Cultural Organization',
#    "Young People's Participation in World Heritage Preservation and Promotion"]},
#  'priorities': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['International assistance']},
#  'agreement': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['International assistance']},
#  'concluded': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['International assistance']},
#  'receiving': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['International assistance']},
#  '31-39': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['International assistance']},
#  '117': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['International assistance']},
#  '[now': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['International Union for the Conservation of Nature and Natural Resources']},
#  'union]': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['International Union for the Conservation of Nature and Natural Resources']},
#  'understood': {'used_in_internal_terms_count': 1,
#   'used_in_internal_terms': ['International protection']},
#  ...}

# %%
for i in wordcount:
    wordlist.append((i, wordcount[i], used_in[i]['used_in_internal_terms_count']))

# %%
wordlist
# Out:
# [('action', 7, 5),
#  ('plan', 4, 5),
#  ('future', 10, 10),
#  ('cultural', 144, 65),
#  ('landscapes', 32, 10),
#  ('prepared', 5, 4),
#  ('unesco', 193, 91),
#  ('expert', 15, 9),
#  ('meeting', 16, 15),
#  ('outstanding', 32, 18),
#  ('universal', 31, 18),
#  ('value', 32, 21),
#  ('held', 16, 12),
#  ('templin', 1, 1),
#  ('germany', 2, 2),
#  ('october', 3, 2),
#  ('1993', 4, 3),
#  ('see', 126, 120),
#  ('von', 10, 7),
#  ('droste', 10, 7),
#  ('et', 10, 63),
#  ('al', 11, 118),
#  ('1995', 28, 16),
#  ('annex', 7, 8),
#  ('1', 23, 96),
#  ('outlines', 3, 3),
#  ('recommendations', 2, 2),
#  ('concerning', 19, 18),
#  ('provision', 5, 6),
#  ('guidance', 8, 8),
#  ('states', 58, 41),
#  ('parties', 41, 31),
#  ('identification', 21, 12),
#  ('assessment', 2, 4),
#  ('nomination', 25, 32),
#  ('management', 16, 12),
#  ('inclusion', 43, 28),
#  ('world', 278, 107),
#  ('heritage', 348, 118),
#  ('list', 126, 60),
#  ('preparation', 5, 4),
#  ('thematic', 5, 4),
#  ('study', 4, 4),
#  ('adopted', 14, 11),
#  ('committee', 73, 45),
#  ('seventeenth', 2, 2),
#  ('session', 12, 16),
#  ('4', 8, 45),
#  ('february', 110, 59),
#  ('1994', 13, 8),
#  ('55-56', 2, 2),
#  ('vii', 1, 1),
#  ('article', 44, 37),
#  ('83', 3, 2),
#  ('convention', 112, 64),
#  ('establishes', 8, 7),
#  ('international', 48, 24),
#  ('centre', 25, 19),
#  ('preservation', 21, 15),
#  ('restoration', 3, 3),
#  ('property', 85, 40),
#  ('rome', 4, 2),
#  ('known', 7, 7),
#  ('iccrom', 10, 4),
#  ('council', 2, 2),
#  ('monuments', 5, 5),
#  ('sites', 22, 14),
#  ('icomos', 21, 14),
#  ('union', 9, 7),
#  ('conservation', 87, 35),
#  ('nature', 13, 11),
#  ('natural', 122, 61),
#  ('resources', 6, 6),
#  ('iucn', 37, 15),
#  ('advisory', 9, 6),
#  ('bodies', 5, 3),
#  ('operational', 114, 61),
#  ('guidelines', 120, 61),
#  ('outline', 3, 8),
#  ('various', 2, 2),
#  ('rôles', 1, 1),
#  ('relation', 5, 6),
#  ('implementation', 13, 12),
#  ('1996', 143, 65),
#  ('also', 20, 17),
#  ('referred', 27, 24),
#  ('organisations', 2, 2),
#  ('paragraphs', 31, 24),
#  ('49', 1, 1),
#  ('50', 1, 3),
#  ('84', 1, 1),
#  ('assistance', 54, 14),
#  ('preparatory', 11, 5),
#  ('emergency', 8, 4),
#  ('technical', 16, 9),
#  ('co-', 2, 10),
#  ('operation', 2, 65),
#  ('training', 13, 5),
#  ('associative', 8, 3),
#  ('landscape', 35, 15),
#  ('one', 32, 33),
#  ('three', 9, 8),
#  ('main', 7, 10),
#  ('categories', 7, 6),
#  ('sixteenth', 4, 4),
#  ('december', 10, 6),
#  ('1992', 11, 6),
#  ('14', 6, 10),
#  ('54-55', 4, 4),
#  ('included', 31, 23),
#  ('11', 18, 14),
#  ('paragraph', 83, 55),
#  ('39', 12, 5),
#  ('iii', 8, 9),
#  ('refers', 21, 20),
#  ('following', 11, 10),
#  ('way', 5, 8),
#  ('final', 1, 1),
#  ('category', 4, 4),
#  ('justifiable', 1, 1),
#  ('virtue', 1, 1),
#  ('powerful', 1, 1),
#  ('religious', 3, 3),
#  ('artistic', 1, 1),
#  ('associations', 1, 1),
#  ('element', 1, 5),
#  ('rather', 1, 1),
#  ('material', 7, 7),
#  ('evidence', 5, 5),
#  ('may', 30, 25),
#  ('insignificant', 1, 1),
#  ('even', 2, 7),
#  ('absentunesco', 1, 1),
#  ('tongariro', 1, 1),
#  ('national', 20, 33),
#  ('park', 5, 5),
#  ('new', 5, 5),
#  ('zealand', 1, 1),
#  ('uluru-kata', 1, 1),
#  ('tjuta', 1, 1),
#  ('australia', 2, 1),
#  ('respectively', 1, 1),
#  ('31', 7, 8),
#  ('january', 5, 5),
#  ('52', 1, 1),
#  ('april', 11, 8),
#  ('asia-pacific', 1, 1),
#  ('regional', 6, 6),
#  ('workshop', 3, 2),
#  ('vi', 6, 52),
#  ('clearly', 13, 8),
#  ('defined', 23, 18),
#  ('continuing', 5, 3),
#  ('organically', 6, 3),
#  ('evolved', 7, 4),
#  ('relict', 6, 4),
#  ('fossil', 6, 4),
#  ('24', 14, 12),
#  ('requires', 5, 5),
#  ('nominated', 13, 11),
#  ('considered', 8, 10),
#  ('meets', 8, 8),
#  ('criteria', 34, 18),
#  ('test', 8, 5),
#  ('authenticity', 28, 15),
#  ('b', 5, 107),
#  ('reproduced', 2, 2),
#  ('meet', 4, 23),
#  ('design', 1, 6),
#  ('workmanship', 1, 1),
#  ('setting', 1, 1),
#  ('case', 6, 8),
#  ('distinctive', 1, 1),
#  ('character', 2, 9),
#  ('components', 2, 2),
#  ('stressed', 2, 2),
#  ('reconstruction', 1, 1),
#  ('acceptable', 1, 1),
#  ('carried', 5, 3),
#  ('basis', 8, 8),
#  ('complete', 2, 4),
#  ('detailed', 1, 1),
#  ('documentation', 10, 8),
#  ('original', 2, 3),
#  ('extent', 3, 3),
#  ('conjecture', 1, 1),
#  ('7', 5, 53),
#  ('text', 4, 3),
#  ('groups', 11, 8),
#  ('urban', 8, 6),
#  ('buildings', 12, 8),
#  ('need', 5, 5),
#  ('8', 14, 27),
#  ('27', 5, 7),
#  ('57', 4, 3),
#  ('58', 3, 2),
#  ('state', 34, 51),
#  ('properties', 96, 43),
#  ('satisfy', 3, 3),
#  ('conditions', 20, 12),
#  ('determination', 2, 2),
#  ('whether', 3, 3),
#  ('met', 4, 10),
#  ('18', 6, 7),
#  ('64', 5, 4),
#  ('e', 2, 159),
#  ('indications', 2, 2),
#  ('completed', 3, 3),
#  ('form', 28, 39),
#  ('heading', 1, 3),
#  ('justification', 2, 2),
#  ('20', 7, 6),
#  ('f', 3, 133),
#  ('iv', 7, 65),
#  ('78', 2, 3),
#  ('refer', 9, 55),
#  ('undefined', 1, 1),
#  ('concept', 6, 5),
#  ('historical', 3, 3),
#  ('28', 2, 2),
#  ('generally', 2, 2),
#  ('acknowledged', 1, 1),
#  ('vague', 1, 1),
#  ('subject', 7, 6),
#  ('different', 5, 5),
#  ('social', 4, 3),
#  ('interpretations', 2, 2),
#  ('application', 4, 4),
#  ('conference', 6, 3),
#  ('nara', 8, 3),
#  ('japan', 1, 1),
#  ('november', 5, 4),
#  ('bergen', 2, 2),
#  ('norway', 2, 2),
#  ('2', 17, 72),
#  ('proceedings', 2, 1),
#  ('preliminary', 1, 1),
#  ('published', 4, 3),
#  ('larson', 8, 4),
#  ('marstein', 2, 2),
#  ('resulted', 1, 1),
#  ('adoption', 1, 1),
#  ('declaration', 1, 1),
#  ('document', 4, 10),
#  ('march', 9, 7),
#  ('inter-american', 2, 2),
#  ('symposium', 3, 2),
#  ('san', 2, 1),
#  ('antonio', 2, 1),
#  ('texas', 1, 1),
#  ('usa', 1, 2),
#  ('co-sponsored', 1, 1),
#  ('usicomos', 1, 1),
#  ('getty', 1, 1),
#  ('cosnervation', 1, 1),
#  ('institute', 1, 1),
#  ('society', 3, 3),
#  ('information', 22, 13),
#  ('sources', 6, 8),
#  ('authorization', 2, 1),
#  ('part', 19, 63),
#  ('completion', 2, 2),
#  ('party', 11, 8),
#  ('agrees', 1, 1),
#  ('allow', 1, 1),
#  ('use', 8, 29),
#  ('photographic', 1, 1),
#  ('materials', 1, 1),
#  ('promotional', 7, 4),
#  ('activities', 11, 8),
#  ('balance', 7, 1),
#  ('first', 6, 6),
#  ('6iii', 1, 1),
#  ('reference', 25, 16),
#  ('efforts', 3, 3),
#  ('maintain', 2, 3),
#  ('reasonable', 1, 1),
#  ('numbers', 3, 1),
#  ('statement', 1, 1),
#  ('reaffirmed', 1, 1),
#  ('15', 13, 12),
#  ('3', 12, 43),
#  ('5', 13, 55),
#  ('conformity', 1, 1),
#  ('spirit', 3, 4),
#  ('instrument', 4, 3),
#  ('section', 13, 8),
#  ('concerned', 3, 2),
#  ('granting', 5, 3),
#  ('111', 3, 3),
#  ('maintained', 1, 1),
#  ('funds', 1, 1),
#  ('allocated', 1, 1),
#  ('projects', 5, 3),
#  ('hand', 2, 1),
#  ('38', 3, 2),
#  ('entitled', 5, 5),
#  ('40-', 1, 1),
#  ('41', 2, 2),
#  ('121', 1, 1),
#  ('number', 14, 13),
#  ('measures', 11, 9),
#  ('recommended', 3, 3),
#  ('achieve', 1, 1),
#  ('40-41', 1, 1),
#  ('inscribed', 20, 15),
#  ('discussion', 2, 2),
#  ('evaluation', 30, 18),
#  ('general', 7, 10),
#  ('principles', 5, 5),
#  ('nominations', 30, 20),
#  ('report', 7, 11),
#  ('notes', 3, 3),
#  ('representativity', 2, 2),
#  ('biogeographical', 3, 3),
#  ('regions', 5, 4),
#  ('events', 1, 1),
#  ('history', 7, 6),
#  ('life', 2, 2),
#  ('6', 11, 70),
#  ('bureau', 20, 16),
#  ('consider', 9, 21),
#  ('substance', 5, 5),
#  ('twentieth', 8, 8),
#  ('sessions', 6, 7),
#  ('provinces', 2, 2),
#  ('suggested', 1, 1),
#  ('appropriate', 4, 4),
#  ('comparative', 8, 5),
#  ('unit', 2, 9),
#  ('grouping', 1, 1),
#  ('similar', 6, 5),
#  ('preparing', 2, 1),
#  ('tentative', 18, 7),
#  ('lists', 8, 7),
#  ('nominating', 7, 6),
#  ('series', 9, 6),
#  ('19iii', 1, 1),
#  ('relative', 2, 2),
#  ('evaluations', 6, 5),
#  ('60', 1, 1),
#  ('17', 4, 5),
#  ('defines', 3, 3),
#  ('buffer', 4, 1),
#  ('zone', 5, 2),
#  ('area', 12, 14),
#  ('surrounding', 1, 2),
#  ('restrictions', 1, 1),
#  ('placed', 2, 2),
#  ('give', 1, 4),
#  ('added', 1, 1),
#  ('layer', 1, 1),
#  ('protection;', 1, 1),
#  ('constituting', 1, 1),
#  ('determined', 3, 3),
#  ('studies', 4, 3),
#  ('whenever', 1, 1),
#  ('necessary', 5, 4),
#  ('proper', 1, 66),
#  ('adequate', 2, 2),
#  ('around', 1, 1),
#  ('provided', 10, 8),
#  ('afforded', 1, 1),
#  ('protection', 51, 25),
#  ('details', 3, 3),
#  ('size', 2, 2),
#  ('characteristics', 5, 5),
#  ('authorized', 1, 1),
#  ('uses', 2, 3),
#  ('well', 3, 5),
#  ('map', 1, 1),
#  ('indicating', 1, 1),
#  ('precise', 2, 4),
#  ('boundaries', 2, 2),
#  ('file', 1, 1),
#  ('relating', 4, 3),
#  ('question', 2, 3),
#  ('september', 2, 2),
#  ('canals', 1, 1),
#  ('chaffeys', 1, 1),
#  ('lock', 1, 1),
#  ('ontario', 1, 1),
#  ('canada', 3, 2),
#  ('canal', 3, 2),
#  ('human-engineered', 1, 1),
#  ('waterway', 1, 1),
#  ('point', 7, 5),
#  ('view', 7, 5),
#  ('technology', 1, 1),
#  ('either', 2, 2),
#  ('intrinsically', 1, 1),
#  ('exceptional', 5, 5),
#  ('example', 7, 8),
#  ('representative', 4, 6),
#  ('monumental', 3, 3),
#  ('work', 6, 16),
#  ('defining', 1, 1),
#  ('features', 8, 7),
#  ('linear', 1, 1),
#  ('integral', 1, 1),
#  ('component', 4, 6),
#  ('complex', 1, 1),
#  ('433', 1, 1),
#  ('secretariat', 9, 6),
#  ('easily', 3, 3),
#  ('identifiable', 1, 1),
#  ('designed', 4, 4),
#  ('created', 3, 3),
#  ('intentionally', 1, 1),
#  ('man', 5, 24),
#  ('embraces', 2, 2),
#  ('garden', 1, 1),
#  ('parkland', 1, 1),
#  ('constructed', 2, 2),
#  ('aesthetic', 4, 4),
#  ('reasons', 2, 2),
#  ('often', 3, 3),
#  ('always', 2, 2),
#  ('associated', 6, 5),
#  ('ensembles', 1, 1),
#  ('cnppa', 5, 3),
#  ('commission', 3, 3),
#  ('parks', 2, 2),
#  ('protected', 7, 6),
#  ('areas', 14, 10),
#  ('six', 1, 5),
#  ('voluntary', 2, 2),
#  ('commissions', 1, 1),
#  ('-', 13, 56),
#  ('largest', 1, 1),
#  ('worldwide', 3, 2),
#  ('network', 7, 4),
#  ('managers', 1, 1),
#  ('specialists', 3, 3),
#  ('mission', 1, 13),
#  ('promote', 2, 2),
#  ('establishment', 4, 4),
#  ('effective', 7, 7),
#  ('terrestrial', 1, 1),
#  ('marine', 1, 1),
#  ('stating', 1, 1),
#  ('carefully', 1, 1),
#  ('selected', 2, 2),
#  ('9', 3, 94),
#  ('comments', 4, 3),
#  ('assessments', 2, 2),
#  ('harmonization', 6, 3),
#  ('performed', 2, 2),
#  ('12', 2, 8),
#  ('requirement', 6, 8),
#  ('belonging', 3, 2),
#  ('certain', 1, 1),
#  ('well-represented', 1, 1),
#  ('prepare', 5, 10),
#  ('type', 4, 6),
#  ('presenting', 3, 3),
#  ('examination', 6, 4),
#  ('requested', 4, 4),
#  ('make', 7, 13),
#  ('18-19', 3, 2),
#  ('61c', 1, 1),
#  ('contain', 6, 3),
#  ('evaluating', 2, 2),
#  ('specifically', 10, 9),
#  ('define', 8, 25),
#  ('throughout', 5, 5),
#  ('made', 11, 11),
#  ('presentation', 19, 9),
#  ('transmission', 12, 6),
#  ('generations', 7, 7),
#  ('makes', 8, 7),
#  ('active', 8, 13),
#  ('taken', 7, 8),
#  ('ensuring', 7, 7),
#  ('1972', 36, 33),
#  ('include', 10, 32),
#  ('definition', 19, 17),
#  ('four', 2, 2),
#  ('essential', 9, 8),
#  ('functions', 5, 5),
#  ('monitor', 5, 9),
#  ('ii', 12, 15),
#  ('monitoring', 29, 8),
#  ('feature', 1, 8),
#  ('prominently', 1, 1),
#  ('term', 12, 18),
#  ('used', 21, 18),
#  ('interchangeably', 7, 6),
#  ('preservationconservation', 1, 1),
#  ('stipulates', 1, 1),
#  ('must', 4, 3),
#  ('legal', 2, 2),
#  ('andor', 12, 10),
#  ('contractual', 1, 1),
#  ('traditional', 4, 3),
#  ('mechanisms', 5, 4),
#  ('ensure', 7, 5),
#  ('7-8', 3, 3),
#  ('without', 4, 4),
#  ('policy', 1, 1),
#  ('scheme', 1, 1),
#  ('34', 1, 4),
#  ('preventive', 1, 1),
#  ('69', 5, 4),
#  ('day-to-day', 1, 1),
#  ('70', 1, 1),
#  ('10', 4, 8),
#  ('26', 2, 5),
#  ('safeguarding', 7, 4),
#  ('understand', 1, 1),
#  ('know', 2, 10),
#  ('meaning', 2, 2),
#  ('safeguard', 1, 4),
#  ('required', 2, 2),
#  ('enhancement', 1, 1),
#  ('xxv', 2, 2),
#  ('french', 3, 3),
#  ('xxxi', 2, 2),
#  ('paris', 3, 3),
#  ('16', 3, 3),
#  ('146', 2, 2),
#  ('signatory', 2, 2),
#  ('june', 3, 6),
#  ('successful', 1, 1),
#  ('responds', 1, 1),
#  ('increasing', 1, 3),
#  ('threats', 2, 2),
#  ('caused', 3, 2),
#  ('poverty', 1, 1),
#  ('many', 2, 4),
#  ('countries', 5, 4),
#  ('neglect', 1, 1),
#  ('unconsidered', 1, 1),
#  ('economic', 3, 3),
#  ('growth', 1, 1),
#  ('development', 4, 5),
#  ('seeks', 3, 3),
#  ('encourage', 1, 2),
#  ('identify', 4, 4),
#  ('protect', 2, 32),
#  ('preserve', 2, 4),
#  ('present', 5, 29),
#  ('cooperation', 1, 1),
#  ('step', 2, 2),
#  ('process', 12, 13),
#  ('identified', 1, 1),
#  ('469', 1, 1),
#  ('fund', 17, 14),
#  ('available', 12, 8),
#  ("world's", 1, 1),
#  ('corrective', 4, 2),
#  ('22', 6, 8),
#  ('46', 3, 5),
#  ('47', 2, 1),
#  ('82', 2, 2),
#  ('specific', 10, 18),
#  ('30', 2, 1),
#  ('outlining', 2, 2),
#  ('nominates', 1, 1),
#  ('integrity', 20, 10),
#  ('threatened', 3, 3),
#  ('human', 5, 7),
#  ('programme', 3, 4),
#  ('procedure', 7, 9),
#  ('danger', 18, 12),
#  ('accordance', 6, 5),
#  ('established', 8, 7),
#  ('requirements', 4, 4),
#  ('43', 2, 4),
#  ('12-15', 2, 2),
#  ('79', 2, 2),
#  ('28-29', 1, 1),
#  ('singular', 1, 1),
#  ('shown', 2, 2),
#  ('purpose', 6, 9),
#  ('shall', 12, 9),
#  ('architectural', 1, 1),
#  ('works', 6, 5),
#  ('sculpture', 1, 1),
#  ('painting', 1, 1),
#  ('elements', 5, 4),
#  ('structures', 2, 2),
#  ('archaeological', 3, 2),
#  ('inscriptions', 1, 1),
#  ('cave', 1, 2),
#  ('dwellings', 1, 1),
#  ('combinations', 1, 1),
#  ('art', 2, 74),
#  ('science;', 2, 1),
#  ('separate', 2, 2),
#  ('connected', 1, 1),
#  ('architecture', 1, 1),
#  ('homogeneity', 1, 1),
#  ('place', 1, 5),
#  ('combined', 2, 2),
#  ('including', 6, 6),
#  ('ethnological', 1, 1),
#  ('anthropological', 1, 1),
#  ('presented', 8, 9),
#  ('7-', 1, 5),
#  ('10-12', 1, 1),
#  ('35', 1, 2),
#  ('42', 2, 1),
#  ('36', 3, 3),
#  ('provide', 11, 20),
#  ('represent', 1, 10),
#  ('designated', 1, 1),
#  ('illustrative', 1, 1),
#  ('evolution', 3, 2),
#  ('settlement', 1, 1),
#  ('time', 12, 15),
#  ('influence', 1, 1),
#  ('physical', 2, 3),
#  ('constraints', 1, 1),
#  ('opportunities', 1, 1),
#  ('environment', 5, 4),
#  ('successive', 2, 2),
#  ('forces', 1, 1),
#  ('external', 1, 1),
#  ('internal', 1, 1),
#  ('terms', 2, 2),
#  ('geo-cultural', 2, 2),
#  ('region', 1, 9),
#  ('capacity', 4, 4),
#  ('illustrate', 2, 2),
#  ('distinct', 2, 4),
#  ('37', 1, 2),
#  ('diversity', 5, 3),
#  ('manifestations', 1, 1),
#  ('interaction', 2, 2),
#  ('humankind', 1, 1),
#  ('reflect', 3, 5),
#  ('techniques', 4, 3),
#  ('sustainable', 5, 4),
#  ('land-use', 3, 1),
#  ('considering', 1, 1),
#  ('limits', 2, 2),
#  ('spiritual', 1, 1),
#  ('contribute', 2, 2),
#  ('modern', 2, 2),
#  ('enhance', 1, 2),
#  ('values', 6, 5),
#  ('continued', 1, 1),
#  ('existence', 1, 1),
#  ('forms', 2, 2),
#  ('supports', 1, 1),
#  ('biological', 5, 4),
#  ('therefore', 3, 3),
#  ('helpful', 1, 1),
#  ('maintaining', 3, 2),
#  ('10-11', 1, 1),
#  ('falling', 2, 2),
#  ('40', 1, 2),
#  ('11-12', 1, 1),
#  ('since', 4, 4),
#  ('several', 2, 2),
#  ('meetings', 9, 8),
#  ('annexes', 3, 3),
#  ('21', 6, 7),
#  ('route', 5, 4),
#  ('least', 3, 3),
#  ('mixed', 2, 2),
#  ('standardised', 1, 1),
#  ('data', 4, 2),
#  ('sheets', 3, 2),
#  ('using', 3, 3),
#  ('wcmc', 6, 2),
#  ('deferred', 4, 2),
#  ('examine', 1, 2),
#  ('classify', 1, 1),
#  ('decisions', 4, 4),
#  ('choose', 1, 1),
#  ('inscribe', 2, 16),
#  ('decide', 3, 3),
#  ('back', 3, 3),
#  ('whose', 1, 1),
#  ('consideration', 3, 3),
#  ('23-25', 3, 3),
#  ('65', 4, 4),
#  ('inscription', 5, 5),
#  ('awaits', 1, 1),
#  ('full', 1, 2),
#  ('commitment', 1, 1),
#  ('government', 3, 6),
#  ('v', 2, 118),
#  ('32', 3, 6),
#  ('recommends', 1, 1),
#  ('towns', 12, 5),
#  ('century', 2, 2),
#  ('pending', 2, 1),
#  ('passage', 1, 1),
#  ('defer', 1, 2),
#  ('in-', 1, 1),
#  ('depth', 1, 1),
#  ('junejuly', 3, 3),
#  ('deletion', 7, 4),
#  ('delisting', 5, 3),
#  ('deleted', 2, 1),
#  ('removed', 1, 1),
#  ('longer', 2, 2),
#  ('threat', 5, 9),
#  ('89', 2, 2),
#  ('deteriorated', 2, 2),
#  ('lost', 2, 2),
#  ('possible', 9, 7),
#  ('54', 2, 7),
#  ('15-17', 1, 1),
#  ('agreed', 1, 1),
#  ('submitted', 5, 4),
#  ('within', 6, 5),
#  ('proposed', 2, 2),
#  ('emblem', 9, 3),
#  ('types', 5, 4),
#  ('provisions', 1, 1),
#  ('request', 5, 11),
#  ('connection', 1, 1),
#  ('suitable', 3, 3),
#  ('suffered', 1, 1),
#  ('severe', 1, 1),
#  ('damage', 1, 1),
#  ('due', 2, 2),
#  ('sudden', 1, 1),
#  ('unexpected', 1, 1),
#  ('phenomena', 1, 1),
#  ('92', 1, 7),
#  ('requests', 7, 5),
#  ('whc5', 1, 1),
#  ('1990d', 1, 1),
#  ('beginning', 1, 1),
#  ('individual', 1, 2),
#  ('authenticityintegrity', 1, 1),
#  ("'cultural", 1, 1),
#  ("landscapes'", 1, 1),
#  ('consultation', 1, 1),
#  ('63', 2, 2),
#  ('h', 1, 142),
#  ('timetable', 4, 3),
#  ('processing', 2, 2),
#  ('timing', 1, 1),
#  ('geological', 2, 2),
#  ('physiographical', 2, 2),
#  ('formations', 4, 2),
#  ('assembly', 1, 1),
#  ('every', 4, 3),
#  ('two', 4, 8),
#  ('years', 4, 4),
#  ('global', 10, 4),
#  ('strategy', 10, 4),
#  ('conceptual', 1, 1),
#  ('framework', 1, 1),
#  ('devised', 2, 1),
#  ('representativeness', 2, 2),
#  ('credibility', 1, 1),
#  ('eighteenth', 2, 2),
#  ('13', 4, 5),
#  ('originally', 1, 1),
#  ('particular', 1, 3),
#  ('group', 6, 14),
#  ('experts', 2, 1),
#  ('parc', 3, 3),
#  ('de', 4, 105),
#  ('la', 3, 56),
#  ('vanoise', 3, 3),
#  ('france', 5, 5),
#  ('affirmed', 2, 3),
#  ('important', 2, 3),
#  ('contributions', 4, 3),
#  ('aims', 2, 2),
#  ('subregional', 1, 1),
#  ('harare', 1, 1),
#  ('zimbabwe', 2, 2),
#  ('53-54', 1, 1),
#  ('8-10', 1, 1),
#  ('26-34', 1, 1),
#  ('inhabited', 7, 4),
#  ('unchanged', 1, 1),
#  ('past', 2, 2),
#  ('historic', 9, 7),
#  ('still', 4, 3),
#  ('careful', 1, 2),
#  ('selection', 2, 2),
#  ('90', 3, 6),
#  ('mentioned', 2, 2),
#  ('routes', 1, 1),
#  ('madrid', 1, 1),
#  ('spain', 1, 1),
#  ('composed', 2, 2),
#  ('tangible', 1, 1),
#  ('significance', 2, 2),
#  ('comes', 1, 1),
#  ('exchanges', 1, 1),
#  ('multi-', 1, 1),
#  ('dimensional', 1, 1),
#  ('dialogue', 1, 1),
#  ('across', 2, 2),
#  ('movement', 1, 1),
#  ('along', 2, 2),
#  ('space', 2, 2),
#  ('437', 1, 1),
#  ('1956', 1, 1),
#  ('formerly', 1, 1),
#  ('1977', 3, 2),
#  ('name', 2, 2),
#  ('changed', 1, 2),
#  ('initials', 1, 1),
#  ('given', 3, 3),
#  ('located', 3, 4),
#  ('rom', 1, 41),
#  ('icc+rom=iccrom', 1, 1),
#  ('attend', 3, 3),
#  ('intergovernmental', 2, 2),
#  ('body', 1, 1),
#  ('provides', 10, 8),
#  ('advice', 2, 2),
#  ('conserve', 2, 2),
#  ('partner', 1, 2),
#  ('whin', 4, 2),
#  ('non-', 2, 2),
#  ('governmental', 2, 4),
#  ('organization', 7, 7),
#  ('founded', 2, 2),
#  ('1965', 1, 1),
#  ('participants', 1, 1),
#  ('procedures', 3, 3),
#  ('set', 6, 7),
#  ('volume', 2, 2),
#  ('year', 5, 8),
#  ('potential', 1, 1),
#  ('94', 2, 12),
#  ('c', 2, 145),
#  ('abbreviated', 1, 1),
#  ('id', 1, 85),
#  ('accession', 1, 1),
#  ('received', 1, 1),
#  ('act', 2, 35),
#  ('putting', 1, 1),
#  ('practice', 1, 1),
#  ('immovable', 4, 2),
#  ('cannot', 1, 1),
#  ('moved', 2, 3),
#  ('opposite', 1, 1),
#  ('movable', 5, 2),
#  ('likely', 1, 1),
#  ('become', 1, 1),
#  ('25', 2, 7),
#  ('indicative', 4, 2),
#  ('sometimes', 3, 3),
#  ('inventory', 10, 3),
#  ('language', 4, 3),
#  ('version', 3, 2),
#  ('orientations', 1, 1),
#  ('devant', 1, 1),
#  ('guider', 1, 1),
#  ('las', 1, 2),
#  ('mise', 1, 1),
#  ('en', 1, 118),
#  ('oeuvre', 1, 1),
#  ('du', 1, 26),
#  ('patrimoine', 2, 2),
#  ('mondial', 2, 2),
#  ('une', 1, 93),
#  ('liste', 1, 3),
#  ('despite', 1, 1),
#  ('english', 1, 1),
#  ('written', 1, 1),
#  ('oral', 1, 1),
#  ('figurative', 1, 1),
#  ('specifications', 1, 1),
#  ("d'information", 1, 1),
#  ('29', 3, 3),
#  ('typical', 2, 1),
#  ('period', 2, 4),
#  ('culture', 2, 2),
#  ('almost', 1, 1),
#  ('wholly', 1, 1),
#  ('preserved', 3, 2),
#  ('remained', 1, 1),
#  ('largely', 1, 1),
#  ('unaffected', 1, 1),
#  ('subsequent', 2, 3),
#  ('developments', 1, 1),
#  ('listed', 2, 2),
#  ('entire', 1, 1),
#  ('town', 2, 5),
#  ('together', 3, 3),
#  ('surroundings', 2, 1),
#  ('protected;', 1, 1),
#  ('characteristic', 3, 8),
#  ('lines', 1, 62),
#  ('midst', 1, 1),
#  ('spatial', 1, 1),
#  ('arrangements', 2, 2),
#  ('stages', 1, 1),
#  ('takes', 1, 1),
#  ('precedence', 1, 1),
#  ('contemporary', 2, 2),
#  ('environment;', 1, 1),
#  ('centres', 1, 1),
#  ('cover', 2, 2),
#  ('exactly', 1, 1),
#  ('ancient', 1, 1),
#  ('enclosed', 1, 1),
#  ('cities', 5, 3),
#  ('determine', 2, 5),
#  ('widest', 2, 2),
#  ('dimensions', 1, 1),
#  ('immediate', 1, 3),
#  ('surroundings;', 1, 1),
#  ('sectors', 2, 2),
#  ('isolated', 1, 1),
#  ('units', 1, 1),
#  ('residual', 1, 1),
#  ('survived', 1, 1),
#  ('coherent', 1, 1),
#  ('disappeared', 1, 1),
#  ('cases', 2, 2),
#  ('surviving', 1, 1),
#  ('bear', 1, 1),
#  ('sufficient', 2, 2),
#  ('testimony', 1, 1),
#  ('former', 1, 2),
#  ('whole', 3, 2),
#  ('inscribing', 1, 1),
#  ('directly', 1, 1),
#  ('44', 7, 5),
#  ('fulfils', 1, 1),
#  ('45', 1, 2),
#  ('summarised', 1, 1),
#  ('follows', 2, 2),
#  ('described', 5, 2),
#  ('44ai', 1, 1),
#  ('key', 3, 2),
#  ('interrelated', 1, 1),
#  ('interdependent', 1, 1),
#  ('relationships', 1, 1),
#  ('44aii', 1, 1),
#  ('demonstrate', 1, 1),
#  ('aspects', 1, 1),
#  ('processes', 2, 2),
#  ('long-term', 1, 1),
#  ('ecosystems', 3, 2),
#  ('44aiii', 1, 1),
#  ('beauty', 2, 2),
#  ('site', 5, 15),
#  ('44aiv', 1, 1),
#  ('habitats', 1, 1),
#  ('diverse', 2, 2),
#  ('fauna', 1, 1),
#  ('flora', 1, 1),
#  ('biogeographic', 2, 5),
#  ('province', 2, 4),
#  ('13-14', 1, 1),
#  ('furthermore', 1, 1),
#  ('examining', 2, 2),
#  ('19', 6, 94),
#  ('criterion', 1, 1),
#  ('80', 1, 2),
#  ('amenable', 1, 1),
#  ('correction', 1, 1),
#  ('administrative', 3, 3),
#  ('legislative', 1, 1),
#  ('cancelling', 1, 1),
#  ('major', 5, 4),
#  ('public', 2, 3),
#  ('project', 5, 6),
#  ('improvement', 1, 1),
#  ('status', 1, 1),
#  ('occasion', 1, 1),
#  ('bii', 2, 2),
#  ('possibility', 1, 1),
#  ('applying', 2, 1),
#  ('thus', 2, 2),
#  ('common', 1, 1),
#  ('approach', 1, 1),
#  ('collective', 2, 2),
#  ('participation', 9, 8),
#  ('community', 1, 1),
#  ('fundamental', 2, 2),
#  ('tools', 1, 1),
#  ('preamble', 3, 2),
#  ('includes', 4, 4),
#  ('significant', 4, 4),
#  ('detail', 1, 4),
#  ('articles', 5, 4),
#  ('19-26', 1, 1),
#  ('secure', 1, 1),
#  ('rehabilitation', 5, 2),
#  ('describes', 3, 2),
#  ('co-operation', 8, 4),
#  ('deadlines', 2, 2),
#  ('order', 5, 5),
#  ('priorities', 1, 1),
#  ('agreement', 1, 1),
#  ('concluded', 1, 1),
#  ('receiving', 1, 1),
#  ('31-39', 1, 1),
#  ('117', 1, 1),
#  ('[now', 1, 1),
#  ('union]', 1, 1),
#  ('understood', 1, 1),
#  ...]
